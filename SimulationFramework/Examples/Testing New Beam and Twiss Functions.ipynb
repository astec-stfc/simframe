# %%
# Useful for debugging
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import numpy as np

# %%
#sys.path.append('../../../')
sys.path.append('../../')

# %%
import SimulationFramework.Modules.Beams as rbf

# %%
beam = rbf.load_file('example_elegant/CLA-S07-DCP-01-SCR.SDDS', verbose=False)

# %%
beam.plot(keys=['cp'], bins=15)

# %%
beam.Sx
# Out:
# 0.00022380784701076016

# %%
beam.St
# Out:
# 8.9589047648731e-13

# %%
np.mean(beam.cp)
# Out:
# 248109789.1853178

# %% [markdown]
# # Twiss

# %%
# Useful for debugging
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('../../')

# %%
import SimulationFramework.Modules.Twiss as rtf

# %%
twiss=rtf.load_directory('example_elegant/')

# %%
twiss.plot(ykeys=['cp_eV'], ykeys2=['sigma_z'])

# %% [markdown]
# # Load Directory with Framework

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../../')
import SimulationFramework.Framework as fw
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
test=fw.frameworkDirectory(directory='../../../ASTRA_COMPARISONRunner-HMCC\\Output\\SimulationDatabase\\0d736224-0061-4702-81d7-f231b226859d', beams=True)

# %%
test.plot(ykeys=['cp_eV'], ykeys2=['eny'], xlim=[0,25])

# %%
test.beams.beta_x
# Out:
# [0.0002777867144725921,
#  38.87980332523645,
#  45.23191545205155,
#  50.74629424535695,
#  10.850708679258355,
#  2.2781183213485985,
#  78.02548789314386,
#  8.68209090463232,
#  4.718836011480897,
#  0.47119246531326847,
#  2.120314913193352,
#  29.93098004147577,
#  41.74473614378759,
#  56.23581291386325,
#  192.3413542843447,
#  215.0577900576291,
#  215.0577900576291,
#  194.54120284258846,
#  97.83995745224155,
#  89.7754766019802,
#  39.85678777647034,
#  33.9557802216866,
#  0.5596369177973854,
#  31.93405333464974,
#  21.376120860431808,
#  2.671195876255557,
#  2.671195876255557]

# %%
test.beams[0]
# Out:
# {'filename': '../../../ASTRA_COMPARISONRunner-HMCC/Output/SimulationDatabase/0d736224-0061-4702-81d7-f231b226859d/laser.hdf5', 'code': 'SimFrame', 'beam': ['reference_particle', 'status', 'x', 'y', 'z', 'px', 'py', 'pz', 'clock', 't', 'charge']}

# %%
test.beams[4].slice_plot(ykey='slice_current')

# %%
test.plot(include_layout=True, include_particles=True, types=['cavity'], xlim=[0,70], grid=True)
