# %%
# Useful for debugging
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import numpy as np

# %%
#sys.path.append('../../../')
sys.path.append('../../')

# %%
import SimulationFramework.Modules.Beams as rbf

# %%
beam = rbf.load_file('example_elegant/CLA-S07-DCP-01-SCR.SDDS', verbose=False)

# %%
beam.plot(keys=['cp'], bins=15)

# %%
beam.Sx
# Out:
# 0.00022380784701076016

# %%
beam.St
# Out:
# 8.9589047648731e-13

# %%
np.mean(beam.cp)
# Out:
# 248109789.1853178

# %% [markdown]
# # Twiss

# %%
# Useful for debugging
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('../../')

# %%
import SimulationFramework.Modules.Twiss as rtf

# %%
twiss=rtf.load_directory('example_elegant/')

# %%
twiss.plot(ykeys=['cp_eV'], ykeys2=['sigma_z'])

# %% [markdown]
# # Load Directory with Framework

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../../')
import SimulationFramework.Framework as fw
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
test=fw.frameworkDirectory(directory='../../../ASTRA_COMPARISONRunner-HMCC\\Output\\SimulationDatabase\\45bd5347-aea9-4d90-9c0d-96b657361d41', beams=True)
# Out:
# ../..\SimulationFramework\Modules\Twiss\astra.py:63: RuntimeWarning: invalid value encountered in true_divide
#   self.append('beta_z', rms_z**2 / ez)
# ../..\SimulationFramework\Modules\Twiss\astra.py:64: RuntimeWarning: divide by zero encountered in true_divide
#   self.append('gamma_z', rms_e**2 / ez)
# ../..\SimulationFramework\Modules\Twiss\astra.py:65: RuntimeWarning: invalid value encountered in true_divide
#   self.append('alpha_z', (-1 * np.sign(mean_zep) * rms_z * rms_e) / ez)

# %%
test.plot(ykeys=['cp_eV'], ykeys2=['eny'], xlim=[0,25])

# %%
test.beams.beta_x
# Out:
# [0.0005426602206862685,
#  21.007779318076075,
#  23.752285912333274,
#  26.101525006435327,
#  6.461443713478482,
#  1.3200778883678477,
#  45.96594752536868,
#  6.235536394529858,
#  4.645343358692856,
#  0.7227707879913983,
#  2.4166339733261553,
#  24.195997202214173,
#  33.14048578815756,
#  42.37817185690533,
#  137.5411219889278,
#  151.37527664091706,
#  151.37527664091706,
#  141.66731693817906,
#  69.07607279272754,
#  67.92118276688247,
#  29.673331550361326,
#  25.171939290764627,
#  0.29061633970480427,
#  26.68719888783391,
#  16.485335631316442,
#  2.4573500505053754,
#  2.4573500505053754]

# %%
test.beams[0]
# Out:
# {'filename': '../../../ASTRA_COMPARISONRunner-HMCC/Output/SimulationDatabase/45bd5347-aea9-4d90-9c0d-96b657361d41/laser.hdf5', 'code': 'SimFrame', 'beam': ['x', 'y', 'z', 'px', 'py', 'pz', 'clock', 't', 'charge']}

# %%
test.beams[4].slice_plot(ykey='slice_current')

# %%
test.plot(include_layout=True, include_particles=True, xlim=[0.,0.8], grid=True)
