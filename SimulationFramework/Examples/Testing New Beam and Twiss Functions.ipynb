# %%
# Useful for debugging
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import numpy as np

# %%
#sys.path.append('../../../')
sys.path.append('../../')

# %%
import SimulationFramework.Modules.Beams as rbf
import matplotlib.pyplot as plt

# %%
beam = rbf.load_file('example_elegant/CLA-S07-DCP-01-SCR.SDDS', verbose=False)

# %%
beam.plot(keys=['t', 'cp'], bins=15)

# %%
beam.plotScreenImage(size=15, colormap=plt.cm.jet, marginals=True,
                                                      numPointsPerSigma=20, screen=True)

# %%
beam.Sx
# Out:
# 0.00022380784701076016

# %%
beam.St
# Out:
# 8.9589047648731e-13

# %%
np.mean(beam.cp)
# Out:
# 248109789.1853178

# %% [markdown]
# # Twiss

# %%
# Useful for debugging
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('../../')

# %%
import SimulationFramework.Modules.Twiss as rtf

# %%
twiss=rtf.load_directory('example_elegant/')

# %%
twiss.plot(ykeys=['cp'], ykeys2=['sigma_z'])

# %% [markdown]
# # Load Directory with Framework

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../../')
import SimulationFramework.Framework as fw
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
test=fw.frameworkDirectory(directory='example_elegant', beams=True)

# %%
test.plot(ykeys=['cp'], ykeys2=['eny'], limits=[0,25])

# %%
test.beams[-1].slice_plot(ykey='slice_current', bins=20)

# %%
test.plot(include_layout=True, include_particles=True, limits=[0.,200], grid=True, ykeys=['eny'], ykeys2=['cp'])

# %%
test.getScreen('CLA-S04-DIA-SCR-02').plotScreenImage(limits=5, colormap=plt.cm.jet, marginals=True,
                                                      numPointsPerSigma=20, screen=True)

# %%
test.beams.mean.z
# Out:
# array([ 4.08983,  5.01083,  6.58343,  6.7485 , 10.8974 , 11.9107 ,
#        12.0502 , 16.2002 , 16.2002 , 17.3136 , 18.4536 , 19.2336 ,
#        19.8777 , 20.4886 , 21.3152 , 23.4572 , 23.4572 , 24.4222 ,
#        25.1794 , 25.8251 , 28.9048 , 31.2678 , 31.2678 , 32.9311 ,
#        33.9851 , 34.118  , 34.118  , 38.2678 , 39.0278 , 39.9311 ,
#        42.6611 , 43.9318 , 46.4411 , 46.5178 , 47.8711 , 49.1011 ,
#        49.2778 , 49.2778 ])

# %%
test.beams.mean.gamma
# Out:
# array([ 68.36137234,  68.3613441 ,  68.36126079,  68.3612526 ,
#        227.31852572, 227.31851874, 227.31851708, 380.8704086 ,
#        380.8704086 , 380.87040613, 380.87040326, 380.8704003 ,
#        380.87039705, 380.870394  , 380.87039094, 380.87038076,
#        380.87038076, 355.69820162, 355.69819918, 355.69819778,
#        355.67690108, 355.64092945, 355.64092945, 355.64094163,
#        355.64095335, 355.64095492, 355.64095492, 485.53975482,
#        485.53975715, 485.53976039, 485.53977134, 485.53977539,
#        484.0165529 , 484.01655342, 484.01655891, 484.01656441,
#        484.01656575, 484.01656575])
