# %%
# Useful for debugging
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import numpy as np

# %%
#sys.path.append('../../../')
sys.path.append('../../')

# %%
import SimulationFramework.Modules.Beams as rbf

# %%
beam = rbf.load_file('example_elegant/CLA-S07-DCP-01-SCR.SDDS', verbose=False)

# %%
beam.plot(keys=['slice_beta_y'], bins=15)
# Out:
# ../..\SimulationFramework\Modules\Beams\Particles\__init__.py:68: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return float(np.cov([u,up])[0,1])
# c:\users\jkj62\appdata\local\continuum\miniconda3\envs\py3qt5test\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\users\jkj62\appdata\local\continuum\miniconda3\envs\py3qt5test\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)

# %%
beam.emittance.enx
# Out:
# 1.9941826783312445e-06

# %%
beam.twiss
# Out:
# {'alpha_x': 0.1265569306402926, 'beta_x': 12.195779710597277, 'alpha_y': 7.132705338456915, 'beta_y': 64.61251188844382}

# %%
beam.slice.slice_beta_y
# Out:
# ../..\SimulationFramework\Modules\Beams\Particles\__init__.py:68: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return float(np.cov([u,up])[0,1])
# c:\users\jkj62\appdata\local\continuum\miniconda3\envs\py3qt5test\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# c:\users\jkj62\appdata\local\continuum\miniconda3\envs\py3qt5test\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# array([  0.        , 279.29337852,  62.21950474,  61.5814789 ,
#         47.51270985,  43.83430993,  53.50814916,  73.30476352,
#         67.32578315,  73.2082025 ,  63.33710571,  93.45768029,
#        104.30483732, 115.39737814,  89.12873181, 695.96975716,
#          0.        ])

# %% [markdown]
# # Twiss

# %%
import SimulationFramework.Modules.Twiss as rtf

# %%
twiss=rtf.load_directory('example_elegant/')

# %%
twiss.plot(ykeys=['cp_eV'], ykeys2=['sigma_z'])

# %% [markdown]
# # Load Directory with Framework

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../../')
import SimulationFramework.Framework as fw
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
test=fw.frameworkDirectory(directory='../../../ASTRA_COMPARISONRunner-HMCC\\Output\\SimulationDatabase\\a769b7c4-cc4c-4f4c-a471-931632027616', beams=True)

# %%
test.plot(ykeys=['cp_eV'], ykeys2=['eny'], xlim=[0,25])

# %%
test.beams.beta_x
# Out:
# [0.00027778671447258095,
#  36.720713809674216,
#  42.71257340086261,
#  47.87644810956718,
#  10.55689330493176,
#  2.2788212031257262,
#  77.12027326561905,
#  8.8110410690702,
#  4.883543778720942,
#  0.49095896724512084,
#  2.21365249702623,
#  31.066863492413486,
#  43.30947145500044,
#  58.305677109972976,
#  199.16792096799907,
#  222.60060399248937,
#  222.60060399248937,
#  201.56647497537608,
#  101.26218895459539,
#  93.0576913083668,
#  41.29390084933924,
#  35.17572446466353,
#  0.5711332665138094,
#  33.18066339154874,
#  22.18512673995439,
#  2.6662108004082152,
#  2.6662108004082152]

# %%
test.beams[0]
# Out:
# {'filename': '../../../ASTRA_COMPARISONRunner-HMCC/Output/SimulationDatabase/a769b7c4-cc4c-4f4c-a471-931632027616/laser.hdf5', 'code': 'SimFrame', 'beam': ['reference_particle', 'status', 'x', 'y', 'z', 'px', 'py', 'pz', 'clock', 't', 'charge']}

# %%
test.beams[4].slice_plot(ykey='slice_current')

# %%
test.plot(include_layout=True, include_particles=True, types=[], xlim=[0,70], grid=False)
