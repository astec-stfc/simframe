# %%
# Useful for debugging
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import numpy as np

# %%
#sys.path.append('../../../')
sys.path.append('../../')

# %%
import SimulationFramework.Modules.Beams as rbf

# %%
beam = rbf.load_file('example_elegant/CLA-S07-DCP-01-SCR.SDDS', verbose=False)

# %%
beam.plot(keys=['cp'], bins=15)

# %%
beam.Sx

# %%
beam.St

# %%
np.mean(beam.cp)

# %% [markdown]
# # Twiss

# %%
# Useful for debugging
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../../')

# %%
import SimulationFramework.Modules.Twiss as rtf

# %%
twiss=rtf.load_directory('example_elegant/')

# %%
twiss.plot(ykeys=['cp_eV'], ykeys2=['sigma_z'])

# %% [markdown]
# # Load Directory with Framework

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../../')
import SimulationFramework.Framework as fw

# %%
test=fw.frameworkDirectory(directory='../../../ASTRA_COMPARISONRunner-HMCC\\Output\\SimulationDatabase\\2a4ad40e-94bb-4bbe-985c-0cfff8caf470', beams=True)

# %%
test.plot(ykeys=['cp_eV'], ykeys2=['eny'], xlim=[0,25])

# %%
test.beams.beta_x
# Out:
# [2.8883290060724542,
#  89.55526282769596,
#  9.256691037004597,
#  4.875023720443496,
#  0.6122831568935877,
#  2.6585935008991246,
#  34.991890398916716,
#  48.614386400762626,
#  63.959597884017946,
#  215.25693699742916,
#  239.93751314311214,
#  239.93751314311214,
#  214.81131309148333,
#  107.06973615206157,
#  95.40496521751486,
#  42.2061680060752,
#  35.92553514629836,
#  0.5446743870599426,
#  34.54934404379611,
#  22.618173921122033,
#  2.7020066514581593,
#  2.7020066514581593]

# %%
test.beams[0]
# Out:
# {'filename': '../../../ASTRA_COMPARISONRunner-HMCC/Output/SimulationDatabase/2a4ad40e-94bb-4bbe-985c-0cfff8caf470/CLA-S02-DIA-SCR-01.hdf5', 'code': 'SimFrame', 'beam': ['x', 'y', 'z', 'px', 'py', 'pz', 'clock', 't', 'charge']}

# %%
test.beams[4].slice_plot(ykey='slice_current')

# %%
test.plot(include_layout=True, include_particles=True, types=[], xlim=[0,70], grid=False)
