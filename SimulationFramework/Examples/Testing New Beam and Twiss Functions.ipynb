# %%
# Useful for debugging
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import numpy as np

# %%
#sys.path.append('../../../')
sys.path.append('../../')

# %%
import SimulationFramework.Modules.Beams as rbf

# %%
beam = rbf.load_file('example_elegant/CLA-S07-DCP-01-SCR.SDDS', verbose=False)

# %%
beam.plot(keys=['cp'], bins=15)

# %%
beam.Sx
# Out:
# 0.00022380784701076016

# %%
beam.St
# Out:
# 8.9589047648731e-13

# %%
np.mean(beam.cp)
# Out:
# 248109789.1853178

# %% [markdown]
# # Twiss

# %%
# Useful for debugging
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('../../')

# %%
import SimulationFramework.Modules.Twiss as rtf

# %%
twiss=rtf.load_directory('example_elegant/')

# %%
twiss.plot(ykeys=['cp'], ykeys2=['sigma_z'])

# %% [markdown]
# # Load Directory with Framework

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../../')
import SimulationFramework.Framework as fw
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
test=fw.frameworkDirectory(directory='example_elegant', beams=True)

# %%
test.plot(ykeys=['cp'], ykeys2=['eny'], xlim=[0,25])

# %%
test.beams[-1].slice_plot(ykey='slice_current', bins=20)

# %%
test.plot(include_layout=True, include_particles=True, xlim=[0.,200], grid=True, ykeys=['ey'], ykeys2=['cp'])

# %%
test.twiss.z
# Out:
# twissData([ 3.37147   ,  3.37147   ,  3.37147   ,  3.448077  ,
#             3.476797  ,  3.577497  ,  3.622777  ,  3.876797  ,
#             3.977497  ,  4.089827  ,  4.089827  ,  4.238067  ,
#             4.268067  ,  4.343617  ,  4.693617  ,  4.693617  ,
#             4.815557  ,  4.845557  ,  5.010827  ,  5.010827  ,
#             5.176797  ,  5.277497  ,  5.576797  ,  5.677497  ,
#             6.389947  ,  6.490647  ,  6.541997  ,  6.583427  ,
#             6.583427  ,  6.660097  ,  6.717497  ,  6.748497  ,
#             6.748497  ,  6.748497  ,  6.7485    ,  6.7485    ,
#             6.7485    ,  6.78904   , 10.85571   , 10.8974    ,
#            10.8974    , 10.8974    , 10.89741   , 10.89741   ,
#            10.89741   , 11.0874    , 11.2974    , 11.3854    ,
#            11.5474    , 11.7724    , 11.8224    , 11.9107    ,
#            11.9107    , 12.0502    , 12.0502    , 12.0502    ,
#            12.0502    , 12.0502    , 12.0502    , 12.0919    ,
#            16.15857   , 16.20017   , 16.20017   , 16.20017   ,
#            16.2002    , 16.2002    , 16.2002    , 16.2002    ,
#            16.3352    , 16.3852    , 16.4182    , 16.5802    ,
#            16.6307    , 16.6807    , 16.8907    , 16.9382    ,
#            17.1002    , 17.3136    , 17.3136    , 17.4382    ,
#            17.6002    , 17.6502    , 17.8602    , 17.9382    ,
#            18.1002    , 18.3252    , 18.3752    , 18.4536    ,
#            18.4536    , 18.5902    , 18.6902    , 19.0402    ,
#            19.1402    , 19.2336    , 19.2336    , 19.3852    ,
#            19.4352    , 19.4852    , 19.5202    , 19.87      ,
#            19.87      , 19.8777    , 19.8777    , 20.2352    ,
#            20.4452    , 20.4886    , 20.4886    , 20.6152    ,
#            20.7152    , 21.0652    , 21.1652    , 21.3152    ,
#            21.3152    , 21.4532    , 21.6152    , 21.7052    ,
#            21.7552    , 21.9532    , 22.1152    , 22.1952    ,
#            22.4052    , 22.4532    , 22.6152    , 22.7652    ,
#            22.8152    , 22.9632    , 23.1252    , 23.1752    ,
#            23.3852    , 23.4572    , 23.4572    , 23.4572    ,
#            23.4572    , 23.4572    , 23.4572    , 23.4572    ,
#            23.5647    , 24.3147    , 24.4222    , 24.4222    ,
#            24.4222    , 24.4222    , 24.4222    , 24.4222    ,
#            24.6532    , 24.8152    , 24.8619    , 24.9119    ,
#            25.0259    , 25.0759    , 25.1151    , 25.1361    ,
#            25.1794    , 25.1794    , 25.4031    , 25.5651    ,
#            25.6151    , 25.8251    , 25.8251    , 25.8251    ,
#            25.8251    , 25.8251    , 25.8251    , 26.0651    ,
#            26.26561096, 27.7658    , 27.96631096, 28.2631    ,
#            28.3131    , 28.3557    , 28.3869    , 28.3993    ,
#            28.8793    , 28.9048    , 28.9048    , 29.2664    ,
#            29.46691096, 30.9671    , 31.16761096, 31.2678    ,
#            31.2678    , 31.2678    , 31.2678    , 31.2678    ,
#            31.2678    , 31.2678    , 31.2678    , 31.5828    ,
#            31.6328    , 31.6578    , 31.6778    , 31.7778    ,
#            31.9278    , 32.2493    , 32.5378    , 32.6378    ,
#            32.7878    , 32.9311    , 32.9311    , 33.818     ,
#            33.868     , 33.9168    , 33.9418    , 33.9851    ,
#            33.9851    , 34.118     , 34.118     , 34.118     ,
#            34.118     , 34.118     , 34.118     , 34.118     ,
#            34.1596    , 38.22627   , 38.26777   , 38.26777   ,
#            38.26777   , 38.2678    , 38.2678    , 38.2678    ,
#            38.4778    , 38.6278    , 38.6778    , 38.7778    ,
#            38.9278    , 39.0278    , 39.0278    , 39.2278    ,
#            39.3778    , 39.4778    , 39.6878    , 39.788     ,
#            39.838     , 39.9311    , 39.9311    , 40.0078    ,
#            40.0078    , 40.3545    , 40.8045    , 41.1078    ,
#            41.1078    , 41.2078    , 41.2578    , 41.3078    ,
#            41.3078    , 41.4078    , 41.5578    , 42.1578    ,
#            42.3078    , 42.4078    , 42.6178    , 42.6611    ,
#            42.6611    , 42.8378    , 42.9878    , 43.158     ,
#            43.208     , 43.225     , 43.525     , 43.5878    ,
#            43.7378    , 43.9318    , 43.9318    , 44.2298    ,
#            44.2298    , 44.5278    , 44.5278    , 44.7378    ,
#            44.8378    , 44.9878    , 45.1118    , 45.1618    ,
#            45.9728    , 46.0228    , 46.2478    , 46.2978    ,
#            46.4411    , 46.4411    , 46.5178    , 46.5178    ,
#            46.7178    , 46.8678    , 47.2558    , 47.4178    ,
#            47.5178    , 47.7278    , 47.7528    , 47.8028    ,
#            47.8711    , 47.8711    , 48.0358    , 48.1978    ,
#            48.5858    , 48.7478    , 48.8478    , 49.0578    ,
#            49.1011    , 49.1011    , 49.2778    , 49.2778    ,
#            49.2778    , 49.2778    ])

# %%
np.array(test.beams.mean.z)
# Out:
# array([ 4.08983,  5.01083,  6.58343,  6.7485 , 10.8974 , 11.9107 ,
#        12.0502 , 16.2002 , 16.2002 , 17.3136 , 18.4536 , 19.2336 ,
#        19.8777 , 20.4886 , 21.3152 , 23.4572 , 23.4572 , 24.4222 ,
#        25.1794 , 25.8251 , 28.9048 , 31.2678 , 31.2678 , 32.9311 ,
#        33.9851 , 34.118  , 34.118  , 38.2678 , 39.0278 , 39.9311 ,
#        42.6611 , 43.9318 , 46.4411 , 46.5178 , 47.8711 , 49.1011 ,
#        49.2778 , 49.2778 ])

# %%
test.beams.mean.gamma
# Out:
# [68.36137234294556,
#  68.36134409519154,
#  68.3612607869367,
#  68.36125260415511,
#  227.3185257169019,
#  227.318518738274,
#  227.31851708481207,
#  380.8704086033375,
#  380.8704086033375,
#  380.8704061307219,
#  380.8704032632187,
#  380.87040029768866,
#  380.87039704701937,
#  380.87039400345753,
#  380.8703909353088,
#  380.87038075790065,
#  380.87038075790065,
#  355.698201621262,
#  355.69819917844836,
#  355.6981977774082,
#  355.6769010824587,
#  355.6409294521487,
#  355.6409294521487,
#  355.64094163447487,
#  355.64095334947325,
#  355.6409549176964,
#  355.6409549176964,
#  485.53975481809164,
#  485.539757150401,
#  485.53976038629617,
#  485.5397713384175,
#  485.53977538575043,
#  484.0165529037962,
#  484.016553422101,
#  484.01655890932136,
#  484.0165644143547,
#  484.0165657474814,
#  484.0165657474814]
