# %%
# Useful for debugging
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import numpy as np

# %%
#sys.path.append('../../../')
sys.path.append('../../')

# %%
import SimulationFramework.Modules.Beams as rbf
import matplotlib.pyplot as plt

# %%
beam = rbf.load_file('example_elegant/CLA-S07-DCP-01-SCR.SDDS', verbose=False)

# %%
beam.plot(keys=['x'], bins=50)

# %%
beam.plot(keys=['t', 'cpz'], bins=15)

# %%
beam.plotScreenImage(size=5, colormap=plt.cm.jet, marginals=True,
                                                      numPointsPerSigma=20, screen=True)

# %%
beam.Sx
# Out:
# 0.00022380784701076016

# %%
beam.St
# Out:
# 8.9589047648731e-13

# %%
beam.mean.cp
# Out:
# 248109789.1853178

# %% [markdown]
# # Twiss

# %%
# Useful for debugging
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('../../')

# %%
import SimulationFramework.Modules.Twiss as rtf

# %%
twiss=rtf.load_directory('example_elegant/')

# %%
twiss.plot(ykeys=['cp'], ykeys2=['sigma_z'])

# %% [markdown]
# # Load Directory with Framework

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../../')
import SimulationFramework.Framework as fw
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
fwdir=fw.frameworkDirectory(directory='example_elegant', beams=True)

# %%
fwdir.plot(ykeys=['cp'], ykeys2=['eny'], limits=[0,25])

# %%
fwdir.beams[-1].slice_plot(ykey='slice_current', bins=20)

# %%
fwdir.plot(include_layout=True, include_particles=True, limits=[0.,200], grid=True, ykeys=['eny'], ykeys2=['cp'])

# %%
fwdir.getScreen('CLA-S04-DIA-SCR-02').plotScreenImage(limits=5, colormap=plt.cm.jet, marginals=False,
                                                      numPointsPerSigma=20, screen=True)

# %%
fwdir.beams.mean.z
# Out:
# array([ 4.08983,  5.01083,  6.58343,  6.7485 , 10.8974 , 11.9107 ,
#        12.0502 , 16.2002 , 16.2002 , 17.3136 , 18.4536 , 19.2336 ,
#        19.8777 , 20.4886 , 21.3152 , 23.4572 , 23.4572 , 24.4222 ,
#        25.1794 , 25.8251 , 28.9048 , 31.2678 , 31.2678 , 32.9311 ,
#        33.9851 , 34.118  , 34.118  , 38.2678 , 39.0278 , 39.9311 ,
#        42.6611 , 43.9318 , 46.4411 , 46.5178 , 47.8711 , 49.1011 ,
#        49.2778 , 49.2778 ])

# %%
fwdir.beams.std.gamma
# Out:
# array([0.85562068, 0.85723451, 0.86094863, 0.86126443, 1.56746051,
#        1.56724025, 1.56718799, 2.30298969, 2.30298969, 2.30291492,
#        2.30282812, 2.30273813, 2.30263905, 2.30254592, 2.3024515 ,
#        2.30213561, 2.30213561, 2.52543232, 2.52535666, 2.52531319,
#        2.52070033, 2.50973198, 2.50973198, 2.50903513, 2.50835996,
#        2.50826892, 2.50826892, 0.31684727, 0.31676022, 0.3166388 ,
#        0.31622372, 0.31607105, 0.90767615, 0.90767206, 0.90762904,
#        0.9075866 , 0.90757618, 0.90757618])
