# %%
# Useful for debugging
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import numpy as np

# %%
#sys.path.append('../../../')
sys.path.append('../../')

# %%
import SimulationFramework.Modules.Beams as rbf

# %%
beam = rbf.load_file('example_elegant/CLA-S07-DCP-01-SCR.SDDS', verbose=False)

# %%
beam.plot(keys=['t', 'p'], bins=25)

# %%
beam.emittance.xn

# %%
beam.twiss

# %%
beam.slice.slice_beta_y

# %% [markdown]
# # Twiss

# %%
import SimulationFramework.Modules.Twiss as rtf

# %%
twiss=rtf.load_directory('example_elegant/')

# %%
twiss.plot(ykeys=['cp_eV'], ykeys2=['sigma_z'])

# %% [markdown]
# # Load Directory with Framework

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../../')
import SimulationFramework.Framework as fw

# %%
test=fw.frameworkDirectory(directory='example_elegant', beams=True)

# %%
test.plot(ykeys=['cp_eV'], ykeys2=['enx'])

# %%
test.beams[0].beta_x
# Out:
# 7.006385620917717

# %%
test.beams('t')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-2a570201d1d2> in <module>
# ----> 1 test.beams('t')
#
# TypeError: 'beamGroup' object is not callable

# %%
test.beams[0].slice_plot(ykey='slice_current')

# %%
test.plot(include_layout=True, include_particles=True, types=[], xlim=[0,70], grid=False)
